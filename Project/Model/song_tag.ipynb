# %%
import json
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
import seaborn as sns

plt.rc('font', family='Malgun Gothic')
sns.set(font="Malgun Gothic",#"NanumGothicCoding", 
        rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
        style='darkgrid')

# %% [markdown]
# # 태그 데이터

# %%
train = pd.read_json('train.json', typ = 'frame')

# %%
train
# Out:
#                                                      tags      id  \
# 0                                                     [락]   61281
# 1                                                [추억, 회상]   10532
# 2                                               [까페, 잔잔한]   76951
# 3       [연말, 눈오는날, 캐럴, 분위기, 따듯한, 크리스마스캐럴, 겨울노래, 크리스마스,...  147456
# 4                                                    [댄스]   27616
# ...                                                   ...     ...
# 115066               [록메탈, 밴드사운드, 록, 락메탈, 메탈, 락, extreme]  120325
# 115067                                               [일렉]  106976
# 115068             [담시, 가족, 눈물, 그리움, 주인공, 나의_이야기, 사랑, 친구]   11343
# 115069                      [잔잔한, 버스, 퇴근버스, Pop, 풍경, 퇴근길]  131982
# 115070                             [노래추천, 팝송추천, 팝송, 팝송모음]  100389
#
#                              plylst_title  \
# 0                                 여행같은 음악
# 1                                 요즘 너 말야
# 2                   편하게, 잔잔하게 들을 수 있는 곡.-
# 3                   크리스마스 분위기에 흠뻑 취하고 싶을때
# 4                                추억의 노래 ㅋ
# ...                                   ...
# 115066                      METAL E'SM #2
# 115067     빠른 리스너를 위한 따끈따끈한 최신 인기 EDM 모음!
# 115068              #1. 눈물이 앞을 가리는 나의_이야기
# 115069  퇴근 버스에서 편히 들으면서 하루를 마무리하기에 좋은 POP
# 115070                FAVORITE POPSONG!!!
#
#                                                     songs  like_cnt  \
# 0       [525514, 129701, 383374, 562083, 297861, 13954...        71
# 1       [432406, 675945, 497066, 120377, 389529, 24427...         1
# 2       [83116, 276692, 166267, 186301, 354465, 256598...        17
# 3       [394031, 195524, 540149, 287984, 440773, 10033...        33
# 4       [159327, 553610, 5130, 645103, 294435, 100657,...         9
# ...                                                   ...       ...
# 115066  [429629, 441511, 612106, 516359, 691768, 38714...         3
# 115067  [321330, 216057, 534472, 240306, 331098, 23288...        13
# 115068  [50512, 249024, 250608, 371171, 229942, 694943...         4
# 115069  [533534, 608114, 343608, 417140, 609009, 30217...         4
# 115070  [26008, 456354, 324105, 89871, 135272, 143548,...        17
#
#                       updt_date
# 0       2013-12-19 18:36:19.000
# 1       2014-12-02 16:19:42.000
# 2       2017-08-28 07:09:34.000
# 3       2019-12-05 15:15:18.000
# 4       2011-10-25 13:54:56.000
# ...                         ...
# 115066  2020-04-17 04:31:11.000
# 115067  2015-12-24 17:23:19.000
# 115068  2019-08-16 20:59:22.000
# 115069  2019-10-25 23:40:42.000
# 115070  2020-04-18 20:35:06.000
#
# [115071 rows x 6 columns]

# %%
# 플레이리스트 아이디(id)와 매핑된 태그(tags) 추출
plylst_tag_map = train[['id', 'tags']]

# unnest tags
plylst_tag_map_unnest = np.dstack(
    (
        np.repeat(plylst_tag_map.id.values, list(map(len, plylst_tag_map.tags))), 
        np.concatenate(plylst_tag_map.tags.values)
    )
)

# unnested 데이터프레임 생성 : plylst_tag_map
plylst_tag_map = pd.DataFrame(data = plylst_tag_map_unnest[0], columns = plylst_tag_map.columns)
plylst_tag_map['id'] = plylst_tag_map['id'].astype(str)

# unnest 객체 제거
del plylst_tag_map_unnest

# %%
plylst_tag_map
# Out:
#             id  tags
# 0        61281     락
# 1        10532    추억
# 2        10532    회상
# 3        76951    까페
# 4        76951   잔잔한
# ...        ...   ...
# 476326  131982   퇴근길
# 476327  100389  노래추천
# 476328  100389  팝송추천
# 476329  100389    팝송
# 476330  100389  팝송모음
#
# [476331 rows x 2 columns]

# %%
plylst_tag_map['tags'].nunique()
# Out:
# 29160

# %%
# 1. 플레이리스트 별 매핑 태그 수 count 테이블 생성 : plylst_tag_cnt
plylst_tag_cnt = pd.DataFrame(plylst_tag_map.groupby('id').tags.nunique())

# %%
# 태그 별 매핑 빈도 수 저장 
tag_cnt = plylst_tag_map.groupby('tags').tags.count().reset_index(name = 'mapping_cnt')
tag_cnt['tags'] = tag_cnt['tags'].astype(str)
tag_cnt['mapping_cnt'] = tag_cnt['mapping_cnt'].astype(int)

# 빈도 수가 1000회 이상인 태그만 저장
tag_cnt = tag_cnt[tag_cnt['mapping_cnt'] >= 100]

# %%
tag_cnt['mapping_cnt'].sort_values()
# Out:
# 27364      100
# 18741      100
# 19033      101
# 19056      101
# 1702       101
#          ...
# 22262    10218
# 12894    10796
# 28675    11215
# 5234     11417
# 7065     16465
# Name: mapping_cnt, Length: 447, dtype: int32

# %%
tag_cnt.sort_values('mapping_cnt',ascending=False)
# Out:
#              tags  mapping_cnt
# 7065         기분전환        16465
# 5234           감성        11417
# 28675          휴식        11215
# 12894         발라드        10796
# 22262         잔잔한        10218
# ...           ...          ...
# 1702   Electronic          101
# 19033          여자          101
# 19056        여자보컬          101
# 27364          하늘          100
# 18741          엑소          100
#
# [447 rows x 2 columns]

# %%
print(tag_cnt['tags'].unique())
# Out:
# ['12월' '1980' '1990' '1990년대' '2000' '2000년대' '2010' '2010년대' '2017'
#  '2019' '7080' '90년대' 'ASMR' 'Billboard' 'CCM' 'Chill' 'DJ' 'EDM'
#  'EDMFloor' 'Electronic' 'HIPHOPLE' 'HipHop' 'JPOP' 'Jazz' 'Lofi' 'M에센셜'
#  'OST' 'Pop' 'RNBSOUL' 'Rap' 'RnB' 'Rock' 'bgm' 'classic' 'dance'
#  'electronica' 'etc' 'groove' 'indie' 'kpop' 'ralalra' 'soul' '가사' '가요'
#  '가을' '가을감성' '가을밤' '가을비' '가족' '가창력' '감각적' '감각적인' '감동' '감미로운' '감성' '감성발라드'
#  '감성음악' '감성자극' '감성적인' '감성팝' '감성힙합' '감수성' '걸그룹' '겨울' '겨울감성' '겨울노래' '겨울밤'
#  '경쾌한' '고독' '고막남친' '고막여친' '고백' '고속도로' '공감' '공부' '공부할때' '공연' '국내' '국내힙합'
#  '국힙' '귀르가즘' '그루브' '그루비' '그리움' '금요일' '기분' '기분업' '기분전환' '기분좋은' '기억' '기타'
#  '까페' '꿀잠' '꿈' '나들이' '나른한' '나만알고싶은' '나만의Best3' '낙엽' '날씨' '남자' '남자아이돌' '낭만'
#  '낮잠' '내적댄스' '내한' '노동요' '노래' '노래방' '노래추천' '노을' '눈' '눈물' '눈오는날' '뉴에이지' '느낌'
#  '느낌있는' '다이어트' '달달' '달달한' '달콤' '달콤한' '댄스' '댄스곡' '더위' '데이트' '독서' '동요'
#  '두근두근' '듀엣' '드라마' '드라마ost' '드라이브' '듣기좋은' '딥하우스' '따듯한' '따뜻한' '따스한' '띵곡'
#  '띵곡들' '라디오' '라운지' '라틴' '락' '랩' '레전드' '레트로' '로맨틱' '록' '록메탈' '리드미컬' '리듬'
#  '리메이크' '마음' '맑은' '매력' '매력적인' '매장' '매장음악' '맥주' '메탈' '멜로디' '명곡' '명상' '모닝콜'
#  '목소리' '몽환' '몽환적' '몽환적인' '무드' '믿고듣는' '바다' '바람' '발라드' '밤' '밤새벽' '밤에듣기좋은노래'
#  '방콕' '방탄소년단' '배경음악' '밴드' '버스' '벚꽃' '별' '보사노바' '보이그룹' '보컬' '봄' '봄날' '봄노래'
#  '봄바람' '봄비' '봄캐롤' '부드러운' '북카페' '분위기' '분위기있는' '불금' '불면증' '블랙뮤직' '블루스' '비'
#  '비오는날' '비트' '빌로우' '빌보드' '빌보드Hot50' '사랑' '사랑노래' '산뜻한' '산책' '상쾌한' '상큼'
#  '상큼한' '새벽' '새벽감성' '새해' '생각' '선선한' '설레임' '설렘' '세련된' '섹시' '센치' '센치한' '셋리스트'
#  '소울' '솔로' '송가인' '쇼미더머니' '수록곡' '숙면' '숨은명곡' '스트레스' '스트레스해소' '스포츠' '슬픈'
#  '슬픈노래' '슬픔' '시대별차트' '시원한' '시작' '시티팝' '시험' '신곡' '신나는' '신나는노래' '신남'
#  '싱어송라이터' '쌀쌀한' '썸' '쓸쓸' '쓸쓸한' '쓸쓸함' '아련한' '아이돌' '아이유' '아침' '아픔' '알앤비'
#  '알엔비' '애니메이션' '애창곡' '야경' '어쿠스틱' '얼터너티브' '에너지' '엑소' '여름' '여름노래' '여름밤'
#  '여성보컬' '여유' '여유로운' '여자' '여자보컬' '여자아이돌' '여행' '여행산책' '연말' '연애' '연인' '연주'
#  '연주곡' '연주음악' '연휴' '열대야' '영국' '영화' '영화OST' '영화음악' '옛날노래' '오후' '올드팝' '와인'
#  '외국힙합' '외로움' '외출' '외힙' '요가' '우울' '우울할때' '운동' '운동할때' '운전' '월드뮤직' '월요병'
#  '월요일' '위로' '유니크' '음색' '음색깡패' '음악' '음악추천' '응원' '이별' '이별노래' '인기' '인디'
#  '인디음악' '인디팝' '일렉' '일렉트로니카' '일렉트로닉' '일본' '일상' '일할때' '자기전에' '자장가' '작곡가'
#  '작업' '잔잔' '잔잔한' '잠' '잠들기전' '장르불문' '장마' '재즈' '재즈추천' '재즈힙합' '저녁' '제이팝'
#  '조용한' '좋아요' '좋은노래' '주말' '중독성' '즐거운' '지친' '지칠때' '지하철' '집' '집중' '짝사랑' '차분한'
#  '찬바람' '찬양' '책' '첫눈' '첫사랑' '청량' '청량한' '청춘' '최신' '추억' '추억회상' '추위' '추천'
#  '추천곡' '출근' '출근길' '취향저격' '취향저격DJ' '친구' '침대' '카페' '카페음악' '캐롤' '커플' '커피'
#  '커피숍' '케이팝' '콘서트' '크리스마스' '클래식' '클럽' '클럽음악' '태교' '퇴근' '퇴근길' '트랩' '트렌드'
#  '트렌디' '트로트' '트로피컬' '파티' '팝' '팝송' '팝송추천' '펍' '페스티벌' '편안한' '편안함' '편집샵'
#  '포근한' '포크' '프로듀서' '플레이리스트' '피곤' '피쉬슈즈' '피아노' '피아노연주곡' '피크닉' '하늘' '하루'
#  '하우스' '한강' '한국힙합' '해외' '해외힙합' '햇살' '행복' '헤어짐' '헬스' '헬스장' '혼술' '혼자' '화이팅'
#  '회상' '후회' '휴가' '휴식' '휴일' '흐린날' '흑인음악' '흥' '흥겨운' '흥폭발' '히든트랙' '히트곡' '힐링'
#  '힘내' '힘들때' '힙스터' '힙한' '힙합' '힙합엘이']

# %%
# 기쁠 때 = 신남, 청량한, 에너지, 즐거운
# 화날 때 = 명상
# 슬플 때 - 잔잔 = 새벽,잔잔
#         - 신남 = 우울할때, 힘내, 화이팅

# %%
#plylst_tag_map=plylst_tag_map.query("tags in ['신남','청량한','에너지','즐거운','명상','슬픔','슬픈','힘내','화이팅']")

# %%
plylst_tag_map['id']=plylst_tag_map['id'].astype('int64')

# %%
plylst_tag_map
# Out:
#             id  tags
# 0        61281     락
# 1        10532    추억
# 2        10532    회상
# 3        76951    까페
# 4        76951   잔잔한
# ...        ...   ...
# 476326  131982   퇴근길
# 476327  100389  노래추천
# 476328  100389  팝송추천
# 476329  100389    팝송
# 476330  100389  팝송모음
#
# [476331 rows x 2 columns]

# %% [markdown]
# # 곡 데이터

# %%
song_meta = pd.read_json('song_meta.json', typ = 'frame')

# %%
song_meta
# Out:
#        song_gn_dtl_gnr_basket  issue_date  \
# 0                    [GN0901]    20140512
# 1            [GN1601, GN1606]    20080421
# 2                    [GN0901]    20180518
# 3            [GN1102, GN1101]    20151016
# 4            [GN1802, GN1801]    20110824
# ...                       ...         ...
# 707984               [GN2001]    19991219
# 707985               [GN0901]    19860000
# 707986       [GN0105, GN0101]    20160120
# 707987       [GN1807, GN1801]    20131217
# 707988       [GN0601, GN0604]    19980000
#
#                                                album_name  album_id  \
# 0                            불후의 명곡 - 7080 추억의 얄개시대 팝송베스트   2255639
# 1                           Bach : Partitas Nos. 2, 3 & 4    376431
# 2                                                     Hit   4698747
# 3       Feeling Right (Everything Is Nice) (Feat. Popc...   2644882
# 4                                                 그남자 그여자   2008470
# ...                                                   ...       ...
# 707984               The Best Best Of The Black President     65254
# 707985                                        True Colors     44141
# 707986                  행보 2015 윤종신 / 작사가 윤종신 Live Part.1   2662866
# 707987                                 명상의 시간을 위한 뉴에이지 음악   2221722
# 707988                                           김경호 Live     34663
#
#        artist_id_basket                                          song_name  \
# 0                [2727]                                           Feelings
# 1               [29966]  Bach : Partita No. 4 In D Major, BWV 828 - II....
# 2                [3361]                    Solsbury Hill (Remastered 2002)
# 3              [838543]  Feeling Right (Everything Is Nice) (Feat. Popc...
# 4              [560160]                                            그남자 그여자
# ...                 ...                                                ...
# 707984         [166499]                           Coffin For Head Of State
# 707985          [11837]                                    Change Of Heart
# 707986            [437]                                             스치듯 안녕
# 707987         [729868]                                               숲의 빛
# 707988            [895]                                       Queen 명곡 멜로디
#
#        song_gn_gnr_basket artist_name_basket      id
# 0                [GN0900]  [Various Artists]       0
# 1                [GN1600]   [Murray Perahia]       1
# 2                [GN0900]    [Peter Gabriel]       2
# 3                [GN1100]           [Matoma]       3
# 4                [GN1800]         [Jude Law]       4
# ...                   ...                ...     ...
# 707984           [GN2000]        [Fela Kuti]  707984
# 707985           [GN0900]     [Cyndi Lauper]  707985
# 707986           [GN0100]              [윤종신]  707986
# 707987           [GN1800]     [Nature Piano]  707987
# 707988           [GN0600]              [김경호]  707988
#
# [707989 rows x 9 columns]

# %%
song_tag=pd.merge(plylst_tag_map,song_meta,how='inner',on='id')

# %%
song_happy=song_tag.query("tags in ['신남','즐거운']")
song_angry=song_tag.query("tags in ['명상','차분한']")
song_sad_down=song_tag.query("tags in ['슬픔']")
song_sad_up=song_tag.query("tags in ['기분업']")

# %%
song_netural=train.sort_values('like_cnt',ascending=False)

# %%
song_netural
# Out:
#                                                      tags      id  \
# 46524        [노동요, 취향저격, 드라이브, Pop, 기분전환, 트렌디, 스트레스, 신나는]   74220
# 85071         [감성, 새벽, 때껄룩, 잔잔한, 휴식, 팝송, 떼껄룩, 힐링, 팝, 신나는]  122388
# 102651     [매장음악, 카페, 러블리쏘, 분위기, 드라이브, 여행, 매력적인, 기분전환, 팝]   26174
# 101464  [흥겨운, 드라이브, Pop, 기분전환, 경쾌한, 외출, 내적댄스, 기분업, 충전,...   72658
# 59894                                      [힐링, 휴식, 기분전환]  113501
# ...                                                   ...     ...
# 104613                                           [어쿠스틱기타]  132666
# 71156                                                 [락]    9179
# 16539                             [잔잔한, 힐링, 명상, 피아노, 차분함]   42577
# 71151                                      [댄스, 댄스곡, 신나는]   61003
# 105964                                               [댄스]   52028
#
#                                     plylst_title  \
# 46524     HOT TRENDY POP: 놓쳐선 안될 'POP' (매주 업데이트)
# 85071                ❤️때껄룩님 ᴛᴀᴋᴇ ᴀ ʟᴏᴏᴋ 플레이리스트❤️
# 102651                  듣다보면 '우와!' 하고 제목을 보게되는 팝
# 101464  약속 있어? 외출 전, 기분 UP 하고 싶을 때 들어봐! [매주 목요일]
# 59894                               감성이 터지는 팝음악들
# ...                                          ...
# 104613                                어쿠스틱 좋은 노래
# 71156                                    라디오 797
# 16539                         따스한 감성을 전하는 피아노 음악
# 71151                           내적댄스 대박! 쉰나는 댄스곡
# 105964                                   s&d 아이돌
#
#                                                     songs  like_cnt  \
# 46524   [159317, 368264, 600999, 274905, 643023, 24070...     53211
# 85071   [532771, 383775, 432753, 176384, 152694, 60126...     41844
# 102651  [40160, 20039, 561488, 20051, 16242, 256568, 7...     27268
# 101464  [111779, 406878, 417725, 129878, 357770, 34879...     23965
# 59894   [342524, 1233, 417666, 394523, 107455, 17206, ...     23732
# ...                                                   ...       ...
# 104613  [110540, 688028, 624009, 593300, 494305, 65325...         0
# 71156   [27673, 112731, 550192, 647261, 509152, 314370...         0
# 16539   [274395, 95894, 201745, 191637, 602182, 200150...         0
# 71151   [690285, 580860, 455945, 114387, 498452, 34758...         0
# 105964  [47244, 43866, 182635, 79748, 54639, 445084, 5...         0
#
#                       updt_date
# 46524   2020-04-17 14:32:23.000
# 85071   2020-04-23 20:58:45.000
# 102651  2020-04-19 21:22:11.000
# 101464  2020-04-22 16:05:39.000
# 59894   2015-07-29 08:25:35.000
# ...                         ...
# 104613  2018-04-24 19:10:01.000
# 71156   2010-11-09 13:28:23.000
# 16539   2019-05-03 10:14:33.000
# 71151   2019-12-21 00:09:24.000
# 105964  2014-12-02 19:38:37.000
#
# [115071 rows x 6 columns]

# %%
song_netural1=song_netural['songs'].iloc[0]

# %%
song_netural1=song_netural1[0:100]

# %%
song_netural2=song_netural['songs'].iloc[1]

# %%
song_netural2=song_netural2[0:100]

# %%
song_netural1.extend(song_netural2)

# %%
len(song_netural1)
# Out:
# 200

# %%
song_netural=pd.DataFrame({'id':song_netural1})

# %%
song_netural
# Out:
#          id
# 0    159317
# 1    368264
# 2    600999
# 3    274905
# 4    643023
# ..      ...
# 195  566420
# 196  152462
# 197  700348
# 198  545260
# 199  183323
#
# [200 rows x 1 columns]

# %%
song_netural=pd.merge(song_netural,song_meta,how='inner',on='id')

# %%
song_netural['tags']='netural'

# %%
song_netural.head()
# Out:
#        id song_gn_dtl_gnr_basket  issue_date                album_name  \
# 0  159317               [GN0901]    20200228                 Confidant
# 1  368264       [GN0908, GN0901]    20200218  How To Love (feat. GRAY)
# 2  600999       [GN0908, GN0901]    20200220              Say It Again
# 3  274905       [GN0908, GN0901]    20200220              Another Life
# 4  643023       [GN0908, GN0901]    20200221                  6 Months
#
#    album_id artist_id_basket                            song_name  \
# 0  10384661        [2731448]                            Confidant
# 1  10388900        [2854781]             How To Love (feat. GRAY)
# 2  10390827        [2742725]                         Say It Again
# 3  10390880        [1134287]  Another Life (Feat. Destiny Rogers)
# 4  10391183        [2640909]                             6 months
#
#   song_gn_gnr_basket artist_name_basket     tags
# 0           [GN0900]         [BabyJake]  netural
# 1           [GN0900]             [ALLY]  netural
# 2           [GN0900]      [Jimmy Smash]  netural
# 3           [GN0900]       [Alex Aiono]  netural
# 4           [GN0900]           [John K]  netural

# %%
song_happy=song_happy.sample(200)
song_angry=song_angry.sample(200)
song_sad_down=song_sad_down.sample(200)
song_sad_up=song_sad_up.sample(200)

# %%
song_happy['tags']='happy'
song_angry['tags']='angry'
song_sad_down['tags']='saddown'
song_sad_up['tags']='sadup'

# %%
song=pd.concat([song_happy,song_angry,song_sad_down,song_sad_up,song_netural],axis=0)

# %%
song
# Out:
#             id     tags    song_gn_dtl_gnr_basket  issue_date  \
# 82824   120791    happy          [GN2104, GN2101]    20110801
# 274053   17907    happy          [GN1013, GN1001]    20050726
# 56216    85206    happy          [GN1601, GN1602]    20141223
# 413683  107860    happy          [GN1807, GN1801]    20150703
# 48034    77251    happy                  [GN0701]    20040101
# ...        ...      ...                       ...         ...
# 195     566420  netural          [GN0901, GN0902]    20170616
# 196     152462  netural                  [GN0901]    20180105
# 197     700348  netural  [GN0401, GN0501, GN0509]    20170719
# 198     545260  netural                  [GN0901]    20170721
# 199     183323  netural          [GN0105, GN0101]    20170723
#
#                                album_name  album_id        artist_id_basket  \
# 82824   2011 워십투어 라이브 IN 서울 `God With Us`   2006864                [101268]
# 274053                            Mr. A-Z    306565                 [50775]
# 56216          Vivaldi: 6 Cello Concertos    191242  [32004, 100378, 32094]
# 413683            커피 향기를 닮은 감미로운 뉴에이지 피아노   2327375                [749191]
# 48034          가요백년사 다시 듣고싶은 그 시절 그 노래...     30446                   [953]
# ...                                   ...       ...                     ...
# 195                             Melodrama  10043187                [725692]
# 196                  This Is Not An Album  10075613               [1133767]
# 197              Walking in the Moonlight  10080593                [995101]
# 198                               Mermaid  10081101               [1274805]
# 199                             복면가왕 121회  10081890        [913168, 780922]
#
#                                           song_name song_gn_gnr_basket  \
# 82824                                  예수님 연약한 날 위해           [GN2100]
# 274053                            Life Is Wonderful           [GN1000]
# 56216       Cello Concerto in G minor RV416 Allegro           [GN1600]
# 413683                                  나를 위한 휴식 공간           [GN1800]
# 48034                                        님계신 전선           [GN0700]
# ...                                             ...                ...
# 195                          Hard Feelings/Loveless           [GN0900]
# 196                                             `93           [GN0900]
# 197     Walking in the Moonlight (Feat. 다원, Lazier)   [GN0500, GN0400]
# 198                                         Mermaid           [GN0900]
# 199             사진 (평창의 마스코트 나야나 수호랑, 넌 내게 반했어 반다비)           [GN0100]
#
#                                        artist_name_basket
# 82824                                         [Disciples]
# 274053                                       [Jason Mraz]
# 56216   [Christophe Coin, The Academy Of Ancient Music...
# 413683                                              [홍유란]
# 48034                                               [금사향]
# ...                                                   ...
# 195                                               [Lorde]
# 196                                              [Youngr]
# 197                                              [서교동의 밤]
# 198                                               [Skott]
# 199                                        [환희, 조이 (JOY)]
#
# [1000 rows x 10 columns]

# %%
song=song[['tags','issue_date','album_name','artist_name_basket','song_name']]

# %%
song=song.reset_index(drop=True)

# %%
song.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tags                1000 non-null   object
#  1   issue_date          1000 non-null   int64
#  2   album_name          1000 non-null   object
#  3   artist_name_basket  1000 non-null   object
#  4   song_name           1000 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 39.2+ KB

# %%
song
# Out:
#         tags  issue_date                         album_name  \
# 0      happy    20110801  2011 워십투어 라이브 IN 서울 `God With Us`
# 1      happy    20050726                            Mr. A-Z
# 2      happy    20141223         Vivaldi: 6 Cello Concertos
# 3      happy    20150703            커피 향기를 닮은 감미로운 뉴에이지 피아노
# 4      happy    20040101         가요백년사 다시 듣고싶은 그 시절 그 노래...
# ..       ...         ...                                ...
# 995  netural    20170616                          Melodrama
# 996  netural    20180105               This Is Not An Album
# 997  netural    20170719           Walking in the Moonlight
# 998  netural    20170721                            Mermaid
# 999  netural    20170723                          복면가왕 121회
#
#                                     artist_name_basket  \
# 0                                          [Disciples]
# 1                                         [Jason Mraz]
# 2    [Christophe Coin, The Academy Of Ancient Music...
# 3                                                [홍유란]
# 4                                                [금사향]
# ..                                                 ...
# 995                                            [Lorde]
# 996                                           [Youngr]
# 997                                           [서교동의 밤]
# 998                                            [Skott]
# 999                                     [환희, 조이 (JOY)]
#
#                                        song_name
# 0                                   예수님 연약한 날 위해
# 1                              Life Is Wonderful
# 2        Cello Concerto in G minor RV416 Allegro
# 3                                    나를 위한 휴식 공간
# 4                                         님계신 전선
# ..                                           ...
# 995                       Hard Feelings/Loveless
# 996                                          `93
# 997  Walking in the Moonlight (Feat. 다원, Lazier)
# 998                                      Mermaid
# 999          사진 (평창의 마스코트 나야나 수호랑, 넌 내게 반했어 반다비)
#
# [1000 rows x 5 columns]

# %%
song_art=song['song_name']
song_album=song['album_name']

# %%
song2="https://www.melon.com/search/total/index.htm?q="+song_album+'+'+song_art

# %%
song2[1]
# Out:
# 'https://www.melon.com/search/total/index.htm?q=Mr. A-Z+Life Is Wonderful'

# %%
song2=pd.DataFrame({'song_url':song2})

# %%
song=pd.concat([song,song2],axis=1)

# %%
song['song_url'].iloc[0]
# Out:
# 'https://www.melon.com/search/total/index.htm?q=2011 워십투어 라이브 IN 서울 `God With Us`+예수님 연약한 날 위해'

# %%
song.to_excel('song_url.xlsx')

# %%
song=pd.read_csv('song.csv',index_col=0)

# %%
song_hap=song.query("tags in ['happy']")

# %%
song_hap
# Out:
#       tags  issue_date                                         album_name  \
# 0    happy    20120803             The Great American Songbook Collection
# 1    happy    20170609                               Cigarettes After Sex
# 2    happy    20180824                                    The Dream Thief
# 3    happy    20180912                                  어린이 인기 동요 베스트 100
# 4    happy    20150710  X-Men: Days Of Future Past - Rogue Cut (Origin...
# ..     ...         ...                                                ...
# 195  happy    19930525                                           Together
# 196  happy    20150528                                         피아노로 쓰는 편지
# 197  happy    20131101                             Did You Hear The Rain?
# 198  happy    19940500              The Return Of N.EX.T Part 1 The Being
# 199  happy    20170216                                            Highway
#
#          artist_name_basket                       song_name  \
# 0            [Beegie Adair]                         Skylark
# 1    [Cigarettes After Sex]      Each Time You Fall in Love
# 2            [Shai Maestro]                 The Dream Thief
# 3         [동요싱싱 (singsing)]                           싹싹닦아라
# 4             [John Ottman]                All Those Voices
# ..                      ...                             ...
# 195          [Julian Bream]  L`encouragement, Op. 34  Waltz
# 196                [Hansol]                      꼭 행복하셔야 해요
# 197           [George Ezra]          Did You Hear The Rain?
# 198                   [넥스트]                          이중 인격자
# 199            [AK PROJECT]                              걷기
#
#                                               song_url
# 0    https://www.melon.com/search/total/index.htm?q...
# 1    https://www.melon.com/search/total/index.htm?q...
# 2    https://www.melon.com/search/total/index.htm?q...
# 3    https://www.melon.com/search/total/index.htm?q...
# 4    https://www.melon.com/search/total/index.htm?q...
# ..                                                 ...
# 195  https://www.melon.com/search/total/index.htm?q...
# 196  https://www.melon.com/search/total/index.htm?q...
# 197  https://www.melon.com/search/total/index.htm?q...
# 198  https://www.melon.com/search/total/index.htm?q...
# 199  https://www.melon.com/search/total/index.htm?q...
#
# [200 rows x 6 columns]

# %%
song_hap.to_csv('song_happy.csv')

# %%
song_hap1=song_hap['song_url']

# %%
song
# Out:
#         tags  issue_date                         album_name  \
# 0      happy    20110801  2011 워십투어 라이브 IN 서울 `God With Us`
# 1      happy    20050726                            Mr. A-Z
# 2      happy    20141223         Vivaldi: 6 Cello Concertos
# 3      happy    20150703            커피 향기를 닮은 감미로운 뉴에이지 피아노
# 4      happy    20040101         가요백년사 다시 듣고싶은 그 시절 그 노래...
# ..       ...         ...                                ...
# 995  netural    20170616                          Melodrama
# 996  netural    20180105               This Is Not An Album
# 997  netural    20170719           Walking in the Moonlight
# 998  netural    20170721                            Mermaid
# 999  netural    20170723                          복면가왕 121회
#
#                                     artist_name_basket  \
# 0                                        ['Disciples']
# 1                                       ['Jason Mraz']
# 2    ['Christophe Coin', 'The Academy Of Ancient Mu...
# 3                                              ['홍유란']
# 4                                              ['금사향']
# ..                                                 ...
# 995                                          ['Lorde']
# 996                                         ['Youngr']
# 997                                         ['서교동의 밤']
# 998                                          ['Skott']
# 999                                 ['환희', '조이 (JOY)']
#
#                                        song_name
# 0                                   예수님 연약한 날 위해
# 1                              Life Is Wonderful
# 2        Cello Concerto in G minor RV416 Allegro
# 3                                    나를 위한 휴식 공간
# 4                                         님계신 전선
# ..                                           ...
# 995                       Hard Feelings/Loveless
# 996                                          `93
# 997  Walking in the Moonlight (Feat. 다원, Lazier)
# 998                                      Mermaid
# 999          사진 (평창의 마스코트 나야나 수호랑, 넌 내게 반했어 반다비)
#
# [1000 rows x 5 columns]

# %%
song=pd.read_excel('song_url.xlsx',index_col=0)

# %%
song
# Out:
#         tags  issue_date                         album_name  \
# 0      happy    20110801  2011 워십투어 라이브 IN 서울 `God With Us`
# 1      happy    20050726                            Mr. A-Z
# 2      happy    20141223         Vivaldi: 6 Cello Concertos
# 3      happy    20150703            커피 향기를 닮은 감미로운 뉴에이지 피아노
# 4      happy    20040101         가요백년사 다시 듣고싶은 그 시절 그 노래...
# ..       ...         ...                                ...
# 995  netural    20170616                          Melodrama
# 996  netural    20180105               This Is Not An Album
# 997  netural    20170719           Walking in the Moonlight
# 998  netural    20170721                            Mermaid
# 999  netural    20170723                          복면가왕 121회
#
#                                     artist_name_basket  \
# 0                                        ['Disciples']
# 1                                       ['Jason Mraz']
# 2    ['Christophe Coin', 'The Academy Of Ancient Mu...
# 3                                              ['홍유란']
# 4                                              ['금사향']
# ..                                                 ...
# 995                                          ['Lorde']
# 996                                         ['Youngr']
# 997                                         ['서교동의 밤']
# 998                                          ['Skott']
# 999                                 ['환희', '조이 (JOY)']
#
#                                        song_name  \
# 0                                   예수님 연약한 날 위해
# 1                              Life Is Wonderful
# 2        Cello Concerto in G minor RV416 Allegro
# 3                                    나를 위한 휴식 공간
# 4                                         님계신 전선
# ..                                           ...
# 995                       Hard Feelings/Loveless
# 996                                          `93
# 997  Walking in the Moonlight (Feat. 다원, Lazier)
# 998                                      Mermaid
# 999          사진 (평창의 마스코트 나야나 수호랑, 넌 내게 반했어 반다비)
#
#                                               song_url
# 0    https://www.melon.com/search/total/index.htm?q...
# 1    https://www.melon.com/search/total/index.htm?q...
# 2    https://www.melon.com/search/total/index.htm?q...
# 3    https://www.melon.com/search/total/index.htm?q...
# 4    https://www.melon.com/search/total/index.htm?q...
# ..                                                 ...
# 995  https://www.melon.com/search/total/index.htm?q...
# 996  https://www.melon.com/search/total/index.htm?q...
# 997  https://www.melon.com/search/total/index.htm?q...
# 998  https://www.melon.com/search/total/index.htm?q...
# 999  https://www.melon.com/search/total/index.htm?q...
#
# [1000 rows x 6 columns]
